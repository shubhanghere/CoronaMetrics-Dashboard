# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('covid data.csv')

# %%
data
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 182650      ZWE    Africa     Zimbabwe  2022-04-25     247598.0       74.0
# 182651      ZWE    Africa     Zimbabwe  2022-04-26     247667.0       69.0
# 182652      ZWE    Africa     Zimbabwe  2022-04-27     247729.0       62.0
# 182653      ZWE    Africa     Zimbabwe  2022-04-28     247784.0       55.0
# 182654      ZWE    Africa     Zimbabwe  2022-04-29     247842.0       58.0
#
# ...

# %%
data.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   10671
# location                                        0
# date                                            0
# total_cases                                  6822
#                                             ...
# human_development_index                     35649
# excess_mortality_cumulative_absolute       176338
# excess_mortality_cumulative                176338
# excess_mortality                           176338
# excess_mortality_cumulative_per_million    176338
# Length: 67, dtype: int64

# %%
CC=pd.read_csv('confirmedcases.csv')

# %%
CC
# Out:
#        continent     location  population        date  total_cases  new_cases  \
# 0           Asia  Afghanistan  39835428.0  24-02-2020          5.0        5.0
# 1           Asia  Afghanistan  39835428.0  25-02-2020          5.0        0.0
# 2           Asia  Afghanistan  39835428.0  26-02-2020          5.0        0.0
# 3           Asia  Afghanistan  39835428.0  27-02-2020          5.0        0.0
# 4           Asia  Afghanistan  39835428.0  28-02-2020          5.0        0.0
# ...          ...          ...         ...         ...          ...        ...
# 182650    Africa     Zimbabwe  15092171.0  25-04-2022     247598.0       74.0
# 182651    Africa     Zimbabwe  15092171.0  26-04-2022     247667.0       69.0
# 182652    Africa     Zimbabwe  15092171.0  27-04-2022     247729.0       62.0
# 182653    Africa     Zimbabwe  15092171.0  28-04-2022     247784.0       55.0
# 182654    Africa     Zimbabwe  15092171.0  29-04-2022     247842.0       58.0
#
# ...

# %%
CC.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
CC.head()
# Out:
#   continent     location  population        date  total_cases  new_cases  \
# 0      Asia  Afghanistan  39835428.0  24-02-2020          5.0        5.0
# 1      Asia  Afghanistan  39835428.0  25-02-2020          5.0        0.0
# 2      Asia  Afghanistan  39835428.0  26-02-2020          5.0        0.0
# 3      Asia  Afghanistan  39835428.0  27-02-2020          5.0        0.0
# 4      Asia  Afghanistan  39835428.0  28-02-2020          5.0        0.0
#
#    new_deaths  total_deaths  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0         NaN           NaN         NaN         NaN          NaN          NaN
# 1         NaN           NaN         NaN         NaN          NaN          NaN
# 2         NaN           NaN         NaN         NaN          NaN          NaN
# 3         NaN           NaN         NaN         NaN          NaN          NaN
# 4         NaN           NaN         NaN         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %%
CC.continent.isnull().sum()
# Out:
# 10671

# %%
df=CC[CC['location']=='Afghanistan']
df['new_cases'].sum()
# Out:
# 178881.0

# %%
CC
# Out:
#        continent     location  population        date  total_cases  new_cases  \
# 0           Asia  Afghanistan  39835428.0  24-02-2020          5.0        5.0
# 1           Asia  Afghanistan  39835428.0  25-02-2020          5.0        0.0
# 2           Asia  Afghanistan  39835428.0  26-02-2020          5.0        0.0
# 3           Asia  Afghanistan  39835428.0  27-02-2020          5.0        0.0
# 4           Asia  Afghanistan  39835428.0  28-02-2020          5.0        0.0
# ...          ...          ...         ...         ...          ...        ...
# 182650    Africa     Zimbabwe  15092171.0  25-04-2022     247598.0       74.0
# 182651    Africa     Zimbabwe  15092171.0  26-04-2022     247667.0       69.0
# 182652    Africa     Zimbabwe  15092171.0  27-04-2022     247729.0       62.0
# 182653    Africa     Zimbabwe  15092171.0  28-04-2022     247784.0       55.0
# 182654    Africa     Zimbabwe  15092171.0  29-04-2022     247842.0       58.0
#
# ...

# %%
CC.dtypes
# Out:
# continent               object
# location                object
# population             float64
# date            datetime64[ns]
# total_cases            float64
# new_cases              float64
# new_deaths             float64
# total_deaths           float64
# Unnamed: 8             float64
# Unnamed: 9             float64
# Unnamed: 10            float64
# Unnamed: 11            float64
# Unnamed: 12            float64
# Unnamed: 13            float64
# dtype: object

# %%
CC['date']= pd.to_datetime(df['date'])

# %%
CC.dtypes
# Out:
# continent               object
# location                object
# population             float64
# date            datetime64[ns]
# total_cases            float64
# new_cases              float64
# new_deaths             float64
# total_deaths           float64
# Unnamed: 8             float64
# Unnamed: 9             float64
# Unnamed: 10            float64
# Unnamed: 11            float64
# Unnamed: 12            float64
# Unnamed: 13            float64
# dtype: object

# %%
CC.to_excel(r'E:\Corona\CovidCases.xlsx', index = False)

# %%
CC.tail()
# Out:
#        continent  location  population date  total_cases  new_cases  \
# 182650    Africa  Zimbabwe  15092171.0  NaT     247598.0       74.0
# 182651    Africa  Zimbabwe  15092171.0  NaT     247667.0       69.0
# 182652    Africa  Zimbabwe  15092171.0  NaT     247729.0       62.0
# 182653    Africa  Zimbabwe  15092171.0  NaT     247784.0       55.0
# 182654    Africa  Zimbabwe  15092171.0  NaT     247842.0       58.0
#
#         new_deaths  total_deaths  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 182650         0.0        5468.0         NaN         NaN          NaN
# 182651         1.0        5469.0         NaN         NaN          NaN
# 182652         0.0        5469.0         NaN         NaN          NaN
# 182653         0.0        5469.0         NaN         NaN          NaN
# 182654         0.0        5469.0         NaN         NaN          NaN
#
#         Unnamed: 11  Unnamed: 12  Unnamed: 13
# 182650          NaN          NaN          NaN
# ...

# %%
df1=pd.read_csv('WHOreport.csv', encoding='latin-1')

# %%
df1
# Out:
#        DateReported      Country  NewCases  TotalCases  NewDeaths  TotalDeaths
# 0        03-01-2020  Afghanistan         0           0          0            0
# 1        04-01-2020  Afghanistan         0           0          0            0
# 2        05-01-2020  Afghanistan         0           0          0            0
# 3        06-01-2020  Afghanistan         0           0          0            0
# 4        07-01-2020  Afghanistan         0           0          0            0
# ...             ...          ...       ...         ...        ...          ...
# 202630   02-05-2022     Zimbabwe         0      247842          0         5469
# 202631   03-05-2022     Zimbabwe         0      247842          0         5469
# 202632   04-05-2022     Zimbabwe         0      247842          0         5469
# 202633   05-05-2022     Zimbabwe         0      247842          0         5469
# 202634   06-05-2022     Zimbabwe         0      247842          0         5469
#
# ...

# %%
df1.dtypes
# Out:
# DateReported    object
# Country         object
# NewCases         int64
# TotalCases       int64
# NewDeaths        int64
# TotalDeaths      int64
# dtype: object

# %%
df1['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d\x92Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...
